# %%
import pandas as pd

# %%
wyposazenie = pd.read_csv(r"C:\Users\patry\Downloads\automoto200.csv", sep="	")
wyposazenie
# Out:
#              ID                                               Link  \
# 0    6067520775  https://www.otomoto.pl/oferta/skoda-rapid-kraj...
# 1    6065070977  https://www.otomoto.pl/oferta/volkswagen-golf-...
# 2    6064956763  https://www.otomoto.pl/oferta/volkswagen-golf-...
# 3    6067520748  https://www.otomoto.pl/oferta/toyota-auris-hyb...
# 4    6061054283  https://www.otomoto.pl/oferta/volkswagen-t-roc...
# ..          ...                                                ...
# 194  6067218977  https://www.otomoto.pl/oferta/porsche-macan-s-...
# 195  6067515377  https://www.otomoto.pl/oferta/audi-q5-1-646zl-...
# 196  6067515370  https://www.otomoto.pl/oferta/audi-q5-1-831zl-...
# 197  6066248137  https://www.otomoto.pl/oferta/opel-antara-zadb...
# 198  6067052075  https://www.otomoto.pl/oferta/volkswagen-t-roc...
#
#                    Nazwa       Cena  \
# 0            Škoda RAPID   38200PLN
# 1    Volkswagen Golf VII  100810PLN
# 2    Volkswagen Golf VII   85260PLN
# ...

# %%
wyposazenie2 = pd.DataFrame(columns=wyposazenie.Wyposażenie[0].split('|'))
wyposazenie2
# Out:
# Empty DataFrame
# Columns: [ABS, ELEKTRYCZNIE USTAWIANE LUSTERKA, PODUSZKA POWIETRZNA PASAŻERA, ALARM, BLUETOOTH, ESP (STABILIZACJA TORU JAZDY), ISOFIX, KURTYNY POWIETRZNE, ŚWIATŁA DO JAZDY DZIENNEJ, CENTRALNY ZAMEK, IMMOBILIZER, RADIO FABRYCZNE, ALUFELGI, CZUJNIKI PARKOWANIA TYLNE, GNIAZDO AUX, KLIMATYZACJA MANUALNA, PODGRZEWANE LUSTERKA BOCZNE, ŚWIATŁA PRZECIWMGIELNE, ELEKTRYCZNE SZYBY PRZEDNIE, PODUSZKA POWIETRZNA KIEROWCY, WSPOMAGANIE KIEROWNICY, ASR (KONTROLA TRAKCJI), ELEKTRYCZNE SZYBY TYLNE, GNIAZDO USB, KOMPUTER POKŁADOWY, SYSTEM START-STOP, WIELOFUNKCYJNA KIEROWNICA]
# Index: []
#
# [0 rows x 27 columns]

# %%
wyposazenie3 = pd.DataFrame(wyposazenie.Wyposażenie[0].split('|'))

# %%
wyp4 = wyposazenie2 + wyposazenie3     
wyp4
# Out:
#       0  ABS ALARM ALUFELGI ASR (KONTROLA TRAKCJI) BLUETOOTH CENTRALNY ZAMEK  \
# 0   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 1   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 2   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 3   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 4   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 5   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 6   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 7   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 8   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 9   NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# 10  NaN  NaN   NaN      NaN                    NaN       NaN             NaN
# ...

# %%
lista = []
for i in wyposazenie.Wyposażenie:
    wyposazenie.Wyposażenie.split('|')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-198450f8dac5> in <module>
#       1 lista = []
#       2 for i in wyposazenie.Wyposażenie:
# ----> 3     wyposazenie.Wyposażenie.split('|')
#       4
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
type(wyposazenie.Wyposażenie[0].split('|'))
# Out:
# list
