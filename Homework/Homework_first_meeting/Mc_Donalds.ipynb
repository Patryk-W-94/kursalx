# %%
import pandas as pd

# %%
df = pd.read_csv("https://www.dropbox.com/s/yruwnkgrqyegw78/Mcdonalds.csv?dl=1")
df = df.sort_index(axis=1, ascending=False)
df
# Out:
#      Vitamin C (% Daily Value)  Vitamin A (% Daily Value)  Trans Fat  \
# 0                            0                         10        0.0
# 1                            0                          6        0.0
# 2                            0                          8        0.0
# 3                            0                         15        0.0
# 4                            0                          6        0.0
# ..                         ...                        ...        ...
# 255                          0                         15        0.5
# 256                          0                         20        1.0
# 257                          0                         10        0.0
# 258                          0                         20        1.0
# 259                          0                         10        0.0
#
#      TotalFat  Total Fat (% Daily Value)  Sugars  Sodium (% Daily Value)  \
# 0        13.0                         20       3                      31
# 1         8.0                         12       3                      32
# 2        23.0                         35       2                      33
# 3        28.0                         43       2                      36
# 4        23.0                         35       2                      37
# ..        ...                        ...     ...                     ...
# 255      17.0                         26      64                      12
# 256      23.0                         35      85                      16
# 257      11.0                         17      43                       8
# 258      32.0                         50     103                      17
# 259      16.0                         25      51                       8
#
#      Sodium     Serving Size  Saturated Fat (% Daily Value)  ...  \
# 0       750   4.8 oz (136 g)                             25  ...
# 1       770   4.8 oz (135 g)                             15  ...
# 2       780   3.9 oz (111 g)                             42  ...
# 3       860   5.7 oz (161 g)                             52  ...
# 4       880   5.7 oz (161 g)                             42  ...
# ..      ...              ...                            ...  ...
# 255     280  10.1 oz (285 g)                             44  ...
# 256     380  13.4 oz (381 g)                             58  ...
# 257     190   6.7 oz (190 g)                             29  ...
# 258     400  14.2 oz (403 g)                             76  ...
# 259     200   7.1 oz (202 g)                             38  ...
#
#      Dietary Fiber (% Daily Value)  Dietary Fiber Cholesterol (% Daily Value)  \
# 0                               17              4                          87
# 1                               17              4                           8
# 2                               17              4                          15
# 3                               17              4                          95
# 4                               17              4                          16
# ..                             ...            ...                         ...
# 255                              4              1                          14
# 256                              5              1                          19
# 257                              2              1                           9
# 258                              9              2                          20
# 259                              5              1                          10
#
#      Cholesterol            Category  Carbohydrates (% Daily Value)  \
# 0            260           Breakfast                             10
# 1             25           Breakfast                             10
# 2             45           Breakfast                             10
# 3            285           Breakfast                             10
# 4             50           Breakfast                             10
# ..           ...                 ...                            ...
# 255           45  Smoothies & Shakes                             27
# 256           55  Smoothies & Shakes                             35
# 257           30  Smoothies & Shakes                             18
# 258           60  Smoothies & Shakes                             38
# 259           30  Smoothies & Shakes                             19
#
#      Carbohydrates  Calories from Fat Calories  Calcium (% Daily Value)
# 0               31                120      300                       25
# 1               30                 70      250                       25
# 2               29                200      370                       25
# 3               30                250      450                       30
# 4               30                210      400                       25
# ..             ...                ...      ...                      ...
# 255             80                150      510                       40
# 256            106                200      690                       50
# 257             53                100      340                       25
# 258            114                290      810                       60
# 259             57                150      410                       30
#
# [260 rows x 24 columns]
